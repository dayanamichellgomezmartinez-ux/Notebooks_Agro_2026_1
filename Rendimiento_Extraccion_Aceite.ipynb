# %% [markdown]
# <a href="https://colab.research.google.com/github/dayanamichellgomezmartinez-ux/Notebooks_Agro_2026_1/blob/main/Rendimiento_Extraccion_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dayana Gomez- 1103949567 Adrian Carmona-1103742140**

# %% [markdown]
# # **Control de Rendimiento en Extraccion de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).(pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L.(r)
#
# $$pa = lt * 0.92$$
#
# $$r=(pa/pr)* 100$$
#
# **Prueba del programa**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Solicitar el nombre del lote de produccion (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo Float).(pr)
# Solicitar los litros de aceite obtenidos (Tipo Float). (lt)
nombre = input("Ingrese el nombre del lote: ")
pr = float(input("Ingrese el peso de los racimos en kg: "))
lt = float(input("Ingrese los litros de aceite obtenidos: "))

#PROCESO: Calcular peso del aceite (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa/pr) * 100

#SALIDA: Informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote: Perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese los litros de aceite obtenidos: 200
# El rendimiento del lote Perico es del 18.4 %

# %% [markdown]
# ```markdown
# ## Explicación del Código de Control de Rendimiento en Extracción de Aceite
#
# Este bloque de código Python solicita al usuario la información necesaria, realiza los cálculos requeridos y luego muestra el resultado final.
#
# ```python
# # ENTRADA: Solicitar el nombre del lote de produccion (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo Float).(pr)
# # Solicitar los litros de aceite obtenidos (Tipo Float). (lt)
# ```
# Estas líneas son comentarios que explican qué tipo de datos se solicitan al usuario y a qué variables se asignarán. Son útiles para entender el propósito de las siguientes líneas de código.
#
# ```python
# nombre = input("Ingrese el nombre del lote: ")
# ```
# Esta línea solicita al usuario que ingrese el nombre del lote de producción. La función `input()` lee la entrada del usuario como una cadena de texto (string), y este valor se almacena en la variable `nombre`.
#
# ```python
# pr = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# Esta línea solicita al usuario el peso de los racimos en kilogramos. La función `input()` obtiene el valor como una cadena, y `float()` lo convierte a un número decimal (float). Este valor se guarda en la variable `pr` (peso de racimos).
#
# ```python
# lt = float(input("Ingrese los litros de aceite obtenidos: "))
# ```
# De manera similar, esta línea solicita la cantidad de litros de aceite obtenidos. El valor ingresado, que es una cadena, se convierte a `float` usando `float()` y se almacena en la variable `lt` (litros de aceite).
#
# ```python
# #PROCESO: Calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Este comentario indica que las siguientes líneas realizarán los cálculos necesarios para obtener el rendimiento.
#
# ```python
# pa = lt * 0.92
# ```
# Esta línea calcula el peso del aceite (`pa`). Multiplica los litros de aceite (`lt`) por la densidad aproximada del aceite (0.92 kg/L). El resultado es el peso del aceite en kilogramos.
#
# ```python
# r = (pa/pr) * 100
# ```
# Aquí se calcula el rendimiento (`r`). Se divide el peso del aceite (`pa`) por el peso de los racimos (`pr`), y el resultado se multiplica por 100 para expresarlo como un porcentaje.
#
# ```python
# #SALIDA: Informar el rendimiento del lote
# ```
# Este comentario señala que la siguiente línea mostrará el resultado al usuario.
#
# ```python
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# Esta línea imprime el resultado final en la consola. Utiliza la función `print()` para concatenar varias cadenas de texto y las variables `nombre` y `r` para formar un mensaje que informa el rendimiento del lote específico.
